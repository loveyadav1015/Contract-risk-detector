# %% [markdown]
# # Contract Risk Detection — Exploratory Data Analysis
#
# This notebook is for exploring the CUAD dataset, understanding clause distributions, and informing preprocessing decisions.
